# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Solo versiones +1.17
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - Para versiones antiguas, ya esta disponible a exepcion de forge, seguir los pasos para usar un forge antiguo



version = '1.20.1' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - oldforge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO] Solo para versiones antiguas -1.17
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

# Para usar paper primero tienes que instalar el vanilla
# Para usar mohist primero tienes que instalar el forge
# Para usar catserver primero tienes que instalar el forge
# Para usar purpur primero tienes que instalar el fabric

server_type = 'mohist'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor 

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

elif server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

elif server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

elif server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version

elif server_type == 'fabric':
    serverURL = 'https://serverjars.com/api/fetchJar/modded/fabric/' + version

elif server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version
    
elif server_type == 'catserver':
    serverURL = "https://serverjars.com/api/fetchJar/modded/catserver/" + version

elif server_type == 'purpur':
    serverURL = "https://serverjars.com/api/fetchJar/servers/purpur/" + version

# Lista de nombres de los archivos

jar_name = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar", 
            'catserver': "catserver.jar", 'purpur': "purpur.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-server-launch.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

if server_type == 'vanilla':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar vanilla.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# Completado!

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)

# Instalar OpenJDK

version = colabconfig["server_version"]

# Ejecuta un comando en la terminal

def installjava17(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 17 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 17")

def installjava11(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 11 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 11")

def installjava8(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 8 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 8")
        
def purgejava(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK purgado correctamente")
    else:
        print("Fallo al purgar OpenJDK")

# Instala OpenJDK 17 si la versión de Minecraft es 1.17 o superior
# Si la versión es inferior, instala OpenJDK 8

if version < "1.14":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 8
    installjava8('sudo apt-get install openjdk-8-jre-headless -y')

elif version >= "1.14" and version < "1.17":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 11
    installjava11('sudo apt-get install openjdk-11-jre-headless -y')

else:
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 17
    installjava17('sudo apt-get install openjdk-17-jre-headless -y')

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok  #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2X5UfopBTpwIAHDImtfOm2sTWyN_4CK8orrVbPSgJFHZPCdz1" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))


elif tunnel_service == "playit":

    subprocess.run(["curl", "-SsL", "https://playit-cloud.github.io/ppa/key.gpg"], check=True)
    subprocess.run(["sudo", "apt-key", "add", "key.gpg"], check=True)

    # Añadiendo el repositorio de Playit.gg
    subprocess.run(["sudo", "curl", "-SsL", "-o", "/etc/apt/sources.list.d/playit-cloud.list", "https://playit-cloud.github.io/ppa/playit-cloud.list"], check=True)

    # Actualizando la lista de paquetes
    subprocess.run(["sudo", "apt", "update"], check=True)

    # Instalando Playit.gg
    result = subprocess.run(["sudo", "apt", "install", "playit"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    # Comprueba si la instalación fue exitosa
    if result.returncode == 0:
        print("Playit.gg installed")
    else:
        print("Failed to install Playit.gg")

    # Iniciando el servidor con Playit.gg
    print('Starting server...')
    subprocess.run(["playit", "&", "java", "$memory_allocation", "$server_flags", "-jar", "$jar_name", "nogui"], check=True)

    # Obteniendo la IP del servidor
    result = subprocess.run(["playit", "status"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print("Tu ip es: " + result.stdout.decode())

#Obtiene la lista de usuarios de JSONPlaceholder
#Para mantener el servidor activo
def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

#Obtener el archivo de configuracion
stype = colabconfig["server_type"]
version = colabconfig["server_version"]

#Imprimir el tipo de servidor y la version
print("Estas jugando a minecraft: " + stype + " en su version: "+ version)

#Si el servidor es de tipo Forge antiguo no va a funcionar
if colabconfig["server_type"] == "forge" and colabconfig["server_version"] < "1.17.1":
    print("La version de Forge no es compatible con este script. Por favor, usa una version de Forge 1.17.1 o superior.")


#Si el servidor es de tipo Forge encontrara los archivos necesarios para ejecutar el servidor

if colabconfig["server_type"] == "forge":

    # Obtiene la versión de Forge
    
    forgefiles = f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/"
    
    forgepreversion = os.listdir(forgefiles)
        
    if forgepreversion:
        
        forgeversion = forgepreversion[0]
        forgeversionchecked = forgeversion.replace(".jar", "")
        print("La versión de Forge es:", forgeversionchecked)
        
    else:
        
        print("No se encontraron archivos en el directorio Forge.")
        
    pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{forgeversionchecked}/unix_args.txt")

    if pathtoforge: # Checa si la lista no esta vacia

        path = pathtoforge[0] # Obtiene la primera ruta de la lista

        print(path)

        # !java @user_jvm_args.txt "@{path}" "$@"

    else:

        print("No se encontro el archivo unix_args.txt.")

#Si el servidor es de tipo Vanilla o paper o mohist o catserver o fabric o purpur

else:

    #Ejecuta el archivo jar del servidor
    
    # !java $memory_allocation $server_flags -jar $jar_name nogui

# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # Espera 1 minuto
# Out:
# el apt cache fue actualizado correctamente
# Minecraft-server     defaultconfigs  mods	      run.sh
# banned-ips.json      eula.txt	     mohist-config    server.properties
# banned-players.json  forge.jar	     mohist.jar       spigot.yml
# bukkit.yml	     forge.jar.log   ops.json	      user_jvm_args.txt
# colabconfig.json     help.yml	     patchouli_books  usercache.json
# commands.yml	     libraries	     permissions.yml  usernamecache.json
# config		     logs	     plugins	      whitelist.json
# crash-reports	     modernfix	     run.bat
# OpenJDK purgado correctamente
# OpenJDK 17 instalado correctamente
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 0.tcp.ngrok.io:12311
# Estas jugando a minecraft: mohist en su version: 1.20.1
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
#
#  ███╗   ███╗  ██████╗  ██╗  ██╗ ██╗ ███████╗ ████████╗
#  ████╗ ████║ ██╔═══██╗ ██║  ██║ ██║ ██╔════╝ ╚══██╔══╝
#  ██╔████╔██║ ██║   ██║ ███████║ ██║ ███████╗    ██║
#  ██║╚██╔╝██║ ██║   ██║ ██╔══██║ ██║ ╚════██║    ██║
#  ██║ ╚═╝ ██║ ╚██████╔╝ ██║  ██║ ██║ ███████║    ██║
#  ╚═╝     ╚═╝  ╚═════╝  ╚═╝  ╚═╝ ╚═╝ ╚══════╝    ╚═╝
#
#
# Thanks for using Mohist - 1.20.1-580, Java(21.0.2) 65.0 PID: 14064
#
# Update in check...
# If you don't want to enable update check, set check_update in mohist-config/mohist.yml to false
# The latest Mohist version is 1.20.1-602 but you have 1.20.1-580. The latest version has been built on 2024-03-09 09:04:15. You should update to fix recent bugs!
# Checking libraries, please wait...
# All libraries are nice :)!
# Searching incompatible mods...
# [14:07:01 INFO]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 47.2.20, --fml.mcVersion, 1.20.1, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20230612.114412, nogui]
# [14:07:01 INFO]: ModLauncher 10.0.9+10.0.9+main.dcd20f30 starting: java version 21.0.2 by Microsoft; OS Linux arch amd64 version 6.2.0-1019-azure
# [14:07:02 INFO]: ImmediateWindowProvider not loading because launch target is forgeserver
# [14:07:02 INFO]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%23111!/ Service=ModLauncher Env=SERVER
# [14:07:03 WARN]: Attempted to select two dependency jars from JarJar which have the same identification: Mod File:  and Mod File: . Using Mod File:
# [14:07:03 WARN]: Attempted to select a dependency jar for JarJar which was passed in as source: geckolib. Using Mod File: /workspaces/codespaces-jupyter/Minecraft-server/mods/geckolib-forge-1.20.1-4.4.2.jar
# [14:07:03 INFO]: Found 13 dependencies adding them to mods collection
# [14:07:06 INFO]: Compatibility level set to JAVA_17
# [14:07:07 INFO]: Launching target 'forgeserver' with arguments [nogui]
# [14:07:07 WARN]: Reference map 'octolib.refmap.json' for octolib.mixins.json could not be read. If this is a development environment you can ignore this message
# [14:07:07 WARN]: Reference map 'graveyard-FORGE-forge-refmap.json' for graveyard-forge.mixins.json could not be read. If this is a development environment you can ignore this message
# [14:07:07 WARN]: Reference map 'simplyswords-forge-refmap.json' for simplyswords.mixins.json could not be read. If this is a development environment you can ignore this message
# [14:07:07 WARN]: Reference map 'coroutil.refmap.json' for coroutil.mixins.json could not be read. If this is a development environment you can ignore this message
# [14:07:07 INFO]: Loading 110 mods:
# 	- additionalstructures 4.2.1
# 	- alexscaves 1.1.4
# 	- alexsmobs 1.22.8
# 	- amendments 1.20-1.1.9
# 	- apotheosis 7.3.1
# 	- aquamirae 6.API15
# 	- architectury 9.2.14
# 	- armorstatues 8.0.5
# 	- ars_nouveau 4.9.0
# 	- artifacts 9.3.0
# 	- atlaslib 1.1.10b
# 	- attributeslib 1.3.0
# 	- awesomedungeon 3.2.0
# 	- awesomedungeonend 3.1.1
# 	- awesomedungeonnether 3.1.1
# 	- balm 7.2.2
# 	- bettercombat 1.8.4+1.20.1
# 	- biomesoplenty 18.0.0.592
# 	- bosses_of_mass_destruction 1.1.1
# 	- bossominium 18.2.0
# 	- caelus 3.1.0+1.20
# 	- carryon 2.1.2.7
# 	- cataclysm 1.0
# 	- cataclysmiccombat 1.2
# 	- cerbons_api 1.0.0
# 	- citadel 2.5.4
# 	- cloth_config 11.1.118
# 	- combatroll 1.3.1+1.20.1
# 	- commoncapabilities 2.9.1
# 	- coroutil 1.20.1-1.3.7
# 	- corpse 1.20.1-1.0.12
# 	- cosmeticarmorreworked 1.20.1-v1a
# 	- create 0.5.1.f
# 	- creativecore 2.11.24
# 	- cristellib 1.1.5
# 	- cupboard 1.20.1-2.5
# 	- curios 5.7.0+1.20.1
# 	- cyclopscore 1.19.0
# 	- darkmobs 1.0.6
# 	- dungeoncrawl 2.3.14
# 	- dungeons_arise 2.1.58-1.20.x
# 	- endofherobrine 1.20.1-1.0.8.2
# 	- endrem 5.2.3-R-1.20.1
# 	- expandability 9.0.0
# 	- farmersdelight 1.20.1-1.2.4
# 	- flywheel 0.6.10-7
# 	- forge 47.2.20
# 	- gamma_beasts 1.0.1
# 	- geckolib 4.4.2
# 	- graveyard 3.1
# 	- hordes 1.3.2b
# 	- iceandfire 2.1.13-1.20.1-beta-4
# 	- idas 1.8.6+1.20.1
# 	- immersive_armors 1.6.1+1.20.1
# 	- immersive_melodies 0.1.0+1.20.1
# 	- immersivecaves 1.3.0
# 	- integrated_api 1.4.1+1.20.1-forge
# 	- irons_spellbooks 1.20.1-3.0.1
# 	- jei 15.3.0.4
# 	- libraryferret 4.0.0
# 	- lootr 0.7.31.77
# 	- magistuarmory 8.11
# 	- man 1.2.1
# 	- minecraft 1.20.1
# 	- mixinextras 0.2.0-beta.8
# 	- mixinsquared 0.1.1
# 	- mob_grinding_utils 1.20.1-1.1.0
# 	- mobplaques 8.0.1
# 	- mohist 1.20.1
# 	- moonlight 1.20-2.11.0
# 	- mr_stellarity 2.0d
# 	- mutantmonsters 8.0.7
# 	- naturescompass 1.20.1-1.11.2-forge
# 	- obscure_api 15
# 	- octolib 0.3
# 	- paraglider 20.1.3
# 	- patchouli 1.20.1-84-FORGE
# 	- placebo 8.6.1
# 	- playeranimator 1.0.2-rc1+1.20
# 	- polymorph 0.49.2+1.20.1
# 	- pots_and_mimics 1.0.2
# 	- puzzlesaccessapi 8.0.7
# 	- puzzlesapi 8.1.4
# 	- puzzleslib 8.1.17
# 	- quark 4.0-438
# 	- realmrpg_demons 0.9.0
# 	- realmrpg_skeletons 1.0.3
# 	- realmrpg_wyrms 1.0.1
# 	- regions_unexplored 0.5.5
# 	- repurposed_structures 7.1.13+1.20.1-forge
# 	- screamfromthecold 1.0.0
# 	- securitycraft 1.9.8
# 	- simplyswords 1.54.0-1.20.1
# 	- snuffles 1.0.7
# 	- sophisticatedbackpacks 3.20.2.1022
# 	- sophisticatedcore 0.6.8.567
# 	- soul_like_armors_reworked 140
# 	- spectrelib 0.13.14+1.20.1
# 	- stalwart_dungeons 1.2.8
# 	- structory 1.3.4
# 	- supplementaries 1.20-2.8.6
# 	- terrablender 3.0.1.4
# 	- terralith 2.4.11
# 	- totw_modded 1.0.3-1.20.1
# 	- twilightforest 4.3.2145
# 	- undergarden 0.8.13
# 	- watut 1.20.1-1.1.0
# 	- waystones 14.1.3
# 	- zeta 1.0-14
# 	- zombieawareness 1.20.1-1.13.1
# [14:07:07 WARN]: Reference map 'Aquamirae.refmap.json' for aquamirae.mixins.json could not be read. If this is a development environment you can ignore this message
# [14:07:07 WARN]: Reference map 'cristellib-forge-refmap.json' for cristellib.mixins.json could not be read. If this is a development environment you can ignore this message
# [14:07:07 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [14:07:07 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [14:07:07 INFO]: Replaced 2 calls to Enchantment#getMaxLevel() in net/minecraft/world/inventory/AnvilMenu
# [14:07:08 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [14:07:08 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [14:07:09 INFO]: Replaced 1 calls to Enchantment#getMaxLevel() in net/minecraft/world/level/storage/loot/functions/EnchantRandomlyFunction
# [14:07:09 INFO]: Replaced 1 calls to Enchantment#isDiscoverable() in net/minecraft/world/level/storage/loot/functions/EnchantRandomlyFunction
# [14:07:09 INFO]: Replaced 2 calls to Enchantment#getMaxLevel() in net/minecraft/world/item/CreativeModeTabs
# [14:07:09 INFO]: Replaced 1 calls to Enchantment#getMaxLevel() in net/minecraft/world/entity/npc/VillagerTrades$EnchantBookForEmeralds
# [14:07:09 INFO]: Replaced 1 calls to Enchantment#isTreasureOnly() in net/minecraft/world/entity/npc/VillagerTrades$EnchantBookForEmeralds
# [14:07:09 INFO]: Replaced 1 calls to Enchantment#isTradeable() in net/minecraft/world/entity/npc/VillagerTrades$EnchantBookForEmeralds
# [14:07:10 INFO]: Initializing MixinExtras via com.llamalad7.mixinextras.service.MixinExtrasServiceImpl(version=0.3.5).
# [14:07:13 INFO]: Replaced 2 calls to Enchantment#getMaxLevel() in net/minecraft/world/item/CreativeModeTabs
# [14:07:15 INFO]: Replaced 5 calls to Enchantment#getMaxLevel() in org/violetmoon/quark/content/tools/module/AncientTomesModule
# [14:07:15 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [14:07:15 INFO]: Patching IForgeItemStack#getEnchantmentLevel
# [14:07:15 INFO]: Replaced 2 calls to Enchantment#getMaxLevel() in net/minecraft/world/inventory/AnvilMenu
# [14:07:19 INFO]: Patching FishingHook#catchingFish
# [14:07:20 INFO]: Replaced 1 calls to Enchantment#getMaxLevel() in net/minecraft/world/level/storage/loot/functions/EnchantRandomlyFunction
# [14:07:20 INFO]: Replaced 1 calls to Enchantment#isDiscoverable() in net/minecraft/world/level/storage/loot/functions/EnchantRandomlyFunction
# [14:07:21 INFO]: forge loader environment detected
# [14:07:22 INFO]: Trying to load common config
# [14:07:22 INFO]: Trying to load client config
# [14:07:22 INFO]: Config files are up to date, skipping data/asset generation
# [14:07:22 INFO]: Loaded config for: cupboard.json
# [14:07:22 INFO]: Registering C2S receiver with id architectury:sync_ids
# [14:07:23 INFO]: Constructing common components for mobplaques:main
# [14:07:23 INFO]: Constructing common components for puzzlesapi:iteminteractions
# [14:07:23 INFO]: Constructing common components for mutantmonsters:main
# [14:07:23 INFO]: Constructing common components for puzzlesapi:slotcycling
# [14:07:23 INFO]: Constructing common components for puzzlesapi:limitlesscontainers
# [14:07:23 INFO]: Constructing common components for puzzlesapi:statues
# [14:07:23 INFO]: Initialize mod Library Ferret
# [14:07:23 ERROR]: Could not find parent net/minecraft/client/renderer/entity/layers/RenderLayer for class com/obscuria/obscureapi/client/renderer/PatreonLayer in classloader cpw.mods.modlauncher.TransformingClassLoader@7856f41a on thread Thread[#39,modloading-worker-0,5,main]
# [14:07:23 ERROR]: An error occurred building event handler
# java.lang.ClassNotFoundException: net.minecraft.client.renderer.entity.layers.RenderLayer
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:157) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.buildEvents(EventSubclassTransformer.java:97) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.transform(EventSubclassTransformer.java:48) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.EventBusEngine.processClass(EventBusEngine.java:26) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.service.ModLauncherService.processClassWithFlags(ModLauncherService.java:32) ~[eventbus-6.0.5.jar:6.0.5+0+master.c510e2cc]
# 	at cpw.mods.modlauncher.LaunchPluginHandler.offerClassNodeToPlugins(LaunchPluginHandler.java:88) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.modlauncher.ClassTransformer.transform(ClassTransformer.java:120) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.modlauncher.TransformingClassLoader.maybeTransformClassBytes(TransformingClassLoader.java:50) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.readerToClass(ModuleClassLoader.java:121) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.lambda$findClass$15(ModuleClassLoader.java:257) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.loadFromModule(ModuleClassLoader.java:267) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.findClass(ModuleClassLoader.java:257) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:144) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	at java.lang.ClassLoader.defineClass0(Native Method) ~[?:?]
# 	at java.lang.System$2.defineClass(System.java:2394) ~[?:?]
# 	at java.lang.invoke.MethodHandles$Lookup$ClassDefiner.defineClass(MethodHandles.java:2505) ~[?:?]
# 	at java.lang.invoke.InnerClassLambdaMetafactory.generateInnerClass(InnerClassLambdaMetafactory.java:361) ~[?:?]
# 	at java.lang.invoke.InnerClassLambdaMetafactory.spinInnerClass(InnerClassLambdaMetafactory.java:286) ~[?:?]
# 	at java.lang.invoke.InnerClassLambdaMetafactory.buildCallSite(InnerClassLambdaMetafactory.java:221) ~[?:?]
# 	at java.lang.invoke.LambdaMetafactory.metafactory(LambdaMetafactory.java:341) ~[?:?]
# 	at java.lang.invoke.BootstrapMethodInvoker.invoke(BootstrapMethodInvoker.java:134) ~[?:?]
# 	at java.lang.invoke.CallSite.makeSite(CallSite.java:316) ~[?:?]
# 	at java.lang.invoke.MethodHandleNatives.linkCallSiteImpl(MethodHandleNatives.java:274) ~[?:?]
# 	at java.lang.invoke.MethodHandleNatives.linkCallSite(MethodHandleNatives.java:264) ~[?:?]
# 	at com.obscuria.obscureapi.client.renderer.PatreonLayer$Mode.<clinit>(PatreonLayer.java:55) ~[obscure_api-15.jar%23355!/:com.obscuria]
# 	at com.obscuria.obscureapi.ObscureAPIConfig$Client.<clinit>(ObscureAPIConfig.java:28) ~[obscure_api-15.jar%23355!/:com.obscuria]
# 	at com.obscuria.obscureapi.ObscureAPIConfig.register(ObscureAPIConfig.java:46) ~[obscure_api-15.jar%23355!/:com.obscuria]
# 	at com.obscuria.obscureapi.ObscureAPI.<init>(ObscureAPI.java:69) ~[obscure_api-15.jar%23355!/:com.obscuria]
# 	at jdk.internal.reflect.DirectConstructorHandleAccessor.newInstance(DirectConstructorHandleAccessor.java:62) ~[?:?]
# 	at java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:502) ~[?:?]
# 	at java.lang.reflect.Constructor.newInstance(Constructor.java:486) ~[?:?]
# 	at net.minecraftforge.fml.javafmlmod.FMLModContainer.constructMod(FMLModContainer.java:76) ~[javafmllanguage-1.20.1-47.2.20.jar%23396!/:?]
# 	at net.minecraftforge.fml.ModContainer.lambda$buildTransitionHandler$10(ModContainer.java:123) ~[fmlcore-1.20.1-47.2.20.jar%23395!/:?]
# 	at java.util.concurrent.CompletableFuture$AsyncRun.run(CompletableFuture.java:1804) [?:?]
# 	at java.util.concurrent.CompletableFuture$AsyncRun.exec(CompletableFuture.java:1796) [?:?]
# 	at java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:387) [?:?]
# 	at java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1312) [?:?]
# 	at java.util.concurrent.ForkJoinPool.scan(ForkJoinPool.java:1843) [?:?]
# 	at java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1808) [?:?]
# 	at java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:188) [?:?]
# [14:07:23 INFO]: Initialized mod Library Ferret
# [14:07:23 ERROR]: Attempted to load class com/obscuria/obscureapi/client/renderer/PatreonLayer for invalid dist DEDICATED_SERVER
# [14:07:24 INFO]: Registering C2S receiver with id artifacts:networking_channel/42a7ad70b1cc371599a0eff744096b8a
# [14:07:24 INFO]: Registering C2S receiver with id artifacts:networking_channel/74a5e841822a3a87854ae896a33430d6
# [14:07:24 INFO]: Registering C2S receiver with id artifacts:networking_channel/eb3d1e2748533430848cadf0f37c7e9c
# [14:07:24 INFO]: Registering C2S receiver with id artifacts:networking_channel/91c8520f19f93b3e8b6a727568e194ab
# [14:07:24 INFO]: Registering C2S receiver with id artifacts:networking_channel/8c2784d778293fd482ed84b8aa5fedb9
# [14:07:24 INFO]: Registered JSON trade offer adapter.
# [14:07:24 INFO]: Here we go! Launching Dungeon Crawl 2.3.14...
# [14:07:24 INFO]: Registering C2S receiver with id magistuarmory:packet_long_reach_attack
# [14:07:24 INFO]: Registering C2S receiver with id magistuarmory:packet_lance_collision
# [14:07:24 INFO]: Mohist mod loading.....
# [14:07:24 INFO]: EventDispatcherRegistry initialized
# [14:07:24 INFO]: Constructing common components for armorstatues:main
# [14:07:24 INFO]: Forge mod loading, version 47.2.20, for MC 1.20.1 with MCP 20230612.114412
# [14:07:24 INFO]: MinecraftForge v47.2.20 Initialized
# [14:07:24 INFO]: NeoForge v47.2.20 Initialized
# /workspaces/codespaces-jupyter/Minecraft-server/config
# [14:07:26 INFO]: Initializing TerraBlender underground biome compat
# [14:07:26 INFO]: Constructing common components for puzzleslib:main
# [14:07:26 INFO]: ExpandAbility here, who dis?
# [14:07:26 INFO]: Replaced 5 calls to Enchantment#getMaxLevel() in org/violetmoon/quark/content/tools/module/AncientTomesModule
# [14:07:26 INFO]: Discovered 160 modules to load.
# [14:07:26 INFO]: Constructing module Abacus...
# [14:07:26 INFO]: Constructing module Adjustable Chat...
# [14:07:26 INFO]: Constructing module Ambient Discs...
# [14:07:26 INFO]: Constructing module Ancient Tomes...
# [14:07:26 INFO]: Replaced 3 calls to Enchantment#getMaxLevel() in org/violetmoon/quark/content/tools/item/AncientTomeItem
# [14:07:26 INFO]: Constructing module Ancient Wood...
# [14:07:26 INFO]: Constructing module Armed Armor Stands...
# [14:07:26 INFO]: Constructing module Auto Walk Keybind...
# [14:07:26 INFO]: Constructing module Automatic Recipe Unlock...
# [14:07:26 INFO]: Constructing module Automatic Tool Restock...
# [14:07:26 INFO]: Constructing module Azalea Wood...
# [14:07:26 INFO]: Constructing module Back Button Keybind...
# [14:07:26 INFO]: Constructing module Backpack...
# [14:07:27 INFO]: Constructing module Beacon Redirection...
# [14:07:27 INFO]: Constructing module Better Elytra Rocket...
# [14:07:27 INFO]: Constructing module Big Stone Clusters...
# [14:07:27 INFO]: Constructing module Blossom Trees...
# [14:07:27 INFO]: Constructing module Bottled Cloud...
# [14:07:27 INFO]: Constructing module Buckets Show Inhabitants...
# [14:07:27 INFO]: Constructing module Camera...
# [14:07:27 INFO]: Constructing module Campfires Boost Elytra...
# [14:07:27 INFO]: Constructing module Celebratory Lamps...
# [14:07:27 INFO]: Constructing module Chains Connect Blocks...
# [14:07:27 INFO]: Constructing module Chest Searching...
# [14:07:27 INFO]: Constructing module Chorus Vegetation...
# [14:07:27 INFO]: Constructing module Chute...
# [14:07:27 INFO]: Constructing module Climate Control Remover...
# [14:07:27 INFO]: Constructing module Color Runes...
# [14:07:27 INFO]: Constructing module Compasses Work Everywhere...
# [14:07:27 INFO]: Constructing module Compressed Blocks...
# [14:07:27 INFO]: Constructing module Coral On Cactus...
# [14:07:27 INFO]: Constructing module Corundum...
# [14:07:27 INFO]: Constructing module Crabs...
# [14:07:27 INFO]: Constructing module Crafter...
# [14:07:27 INFO]: Constructing module Crate...
# [14:07:27 INFO]: Constructing module Diamond Repair...
# [14:07:27 INFO]: Constructing module Dispensers Place Blocks...
# [14:07:27 INFO]: Constructing module Double Door Opening...
# [14:07:27 INFO]: Constructing module Dragon Scales...
# [14:07:27 INFO]: Constructing module Duskbound Blocks...
# [14:07:27 INFO]: Constructing module Dyeable Item Frames...
# [14:07:27 INFO]: Constructing module Easy Transfering...
# [14:07:27 INFO]: Constructing module Elytra Indicator...
# [14:07:27 INFO]: Constructing module Emotes...
# [14:07:27 INFO]: Constructing module Enchantment Predicates...
# [14:07:27 INFO]: Constructing module Enchantments Begone...
# [14:07:27 INFO]: Constructing module Ender Watcher...
# [14:07:27 INFO]: Constructing module Endermosh Music Disc...
# [14:07:27 INFO]: Constructing module Enhanced Ladders...
# [14:07:27 INFO]: Constructing module Expanded Item Interactions...
# [14:07:27 INFO]: Constructing module Fairy Rings...
# [14:07:27 INFO]: Constructing module Feeding Trough...
# [14:07:27 INFO]: Constructing module Forgotten...
# [14:07:27 INFO]: Constructing module Foxhound...
# [14:07:27 INFO]: Constructing module Framed Glass...
# [14:07:27 INFO]: Constructing module Game Nerfs...
# [14:07:27 INFO]: Constructing module Glass Item Frame...
# [14:07:27 INFO]: Constructing module Glass Shard...
# [14:07:27 INFO]: Constructing module Glimmering Weald...
# [14:07:27 INFO]: Constructing module Gold Bars...
# [14:07:27 INFO]: Constructing module Gold Tools Have Fortune...
# [14:07:27 INFO]: Constructing module Grab Chickens...
# [14:07:27 INFO]: Constructing module Grate...
# [14:07:27 INFO]: Constructing module Gravisand...
# [14:07:27 INFO]: Constructing module Greener Grass...
# [14:07:27 INFO]: Constructing module Hedges...
# [14:07:27 INFO]: Constructing module Hoe Harvesting...
# [14:07:27 INFO]: Constructing module Hollow Logs...
# [14:07:27 INFO]: Constructing module Horses Swim...
# [14:07:27 INFO]: Constructing module Hotbar Changer...
# [14:07:27 INFO]: Constructing module Improved Sponges...
# [14:07:27 INFO]: Constructing module Improved Tooltips...
# [14:07:27 INFO]: Constructing module Industrial Palette...
# [14:07:27 INFO]: Constructing module Inventory Sorting...
# [14:07:27 INFO]: Constructing module Iron Rod...
# [14:07:27 INFO]: Constructing module Item Sharing...
# [14:07:27 INFO]: Constructing module Japanese Palette...
# [14:07:27 INFO]: Constructing module Leaf Carpet...
# [14:07:27 INFO]: Constructing module Lock Rotation...
# [14:07:27 INFO]: Constructing module Long Range Pick Block...
# [14:07:27 INFO]: Constructing module Magnets...
# [14:07:27 INFO]: Constructing module Map Washing...
# [14:07:27 INFO]: Constructing module Matrix Enchanting...
# [14:07:27 INFO]: Constructing module Metal Buttons...
# [14:07:27 INFO]: Constructing module Microcrafting Helper...
# [14:07:27 INFO]: Constructing module Midori...
# [14:07:27 INFO]: Constructing module Monster Box...
# [14:07:27 INFO]: Constructing module More Banner Layers...
# [14:07:27 INFO]: Constructing module More Brick Types...
# [14:07:27 INFO]: Constructing module More Mud Blocks...
# [14:07:27 INFO]: Constructing module More Note Block Sounds...
# [14:07:27 INFO]: Constructing module More Potted Plants...
# [14:07:27 INFO]: Constructing module Narrator Readout...
# [14:07:27 INFO]: Constructing module Nether Brick Fence Gate...
# [14:07:27 INFO]: Constructing module Nether Obsidian Spikes...
# [14:07:27 INFO]: Constructing module New Stone Types...
# [14:07:27 INFO]: Constructing module No Durability On Cosmetics...
# [14:07:27 INFO]: Constructing module No More Lava Pockets...
# [14:07:27 INFO]: Constructing module Obsidian Plate...
# [14:07:27 INFO]: Constructing module Overlay Shader...
# [14:07:27 INFO]: Constructing module Parrot Eggs...
# [14:07:27 INFO]: Constructing module Pat The Dogs...
# [14:07:27 INFO]: Constructing module Pathfinder Maps...
# [14:07:27 INFO]: Constructing module Permafrost...
# [14:07:27 INFO]: Constructing module Pickarang...
# [14:07:27 INFO]: Constructing module Pig Litters...
# [14:07:27 INFO]: Constructing module Pipes...
# [14:07:27 INFO]: Constructing module Pistons Move Tile Entities...
# [14:07:27 INFO]: Constructing module Poison Potato Usage...
# [14:07:27 INFO]: Constructing module Quick Armor Swapping...
# [14:07:27 INFO]: Constructing module Rainbow Lamps...
# [14:07:27 INFO]: Constructing module Raw Metal Bricks...
# [14:07:27 INFO]: Constructing module Reacharound Placing...
# [14:07:27 INFO]: Constructing module Redstone Randomizer...
# [14:07:27 INFO]: Constructing module Renewable Spore Blossoms...
# [14:07:27 INFO]: Constructing module Replace Scaffolding...
# [14:07:27 INFO]: Constructing module Rope...
# [14:07:27 INFO]: Constructing module Safer Creatures...
# [14:07:27 INFO]: Constructing module Seed Pouch...
# [14:07:27 INFO]: Constructing module Shear Vines...
# [14:07:27 INFO]: Constructing module Shiba...
# [14:07:27 INFO]: Constructing module Shingles...
# [14:07:27 INFO]: Constructing module Shulker Packing...
# [14:07:27 INFO]: Constructing module Simple Harvest...
# [14:07:27 INFO]: Constructing module Skull Pikes...
# [14:07:27 INFO]: Constructing module Slabs To Blocks...
# [14:07:27 INFO]: Constructing module Slime In A Bucket...
# [14:07:27 INFO]: Constructing module Slimes To Magma Cubes...
# [14:07:27 INFO]: Constructing module Snow Golem Player Heads...
# [14:07:27 INFO]: Constructing module Soul Candles...
# [14:07:27 INFO]: Constructing module Soul Sandstone...
# [14:07:27 INFO]: Constructing module Spawner Replacer...
# [14:07:27 INFO]: Constructing module Spiral Spires...
# [14:07:27 INFO]: Constructing module Stonelings...
# [14:07:27 INFO]: Constructing module Stools...
# [14:07:27 INFO]: Constructing module Sturdy Stone...
# [14:07:27 INFO]: Constructing module Thatch...
# [14:07:27 INFO]: Constructing module Tiny Potato...
# [14:07:27 INFO]: Constructing module Torch Arrow...
# [14:07:27 INFO]: Constructing module Toretoise...
# [14:07:27 INFO]: Constructing module Totem Of Holding...
# [14:07:27 INFO]: Constructing module Trowel...
# [14:07:27 INFO]: Constructing module Usage Ticker...
# [14:07:27 INFO]: Constructing module Uses For Curses...
# [14:07:27 INFO]: Constructing module Utility Recipes...
# [14:07:27 INFO]: Constructing module Variant Animal Textures...
# [14:07:27 INFO]: Constructing module Variant Bookshelves...
# [14:07:27 INFO]: Constructing module Variant Chests...
# [14:07:27 INFO]: Constructing module Variant Furnaces...
# [14:07:27 INFO]: Constructing module Variant Ladders...
# [14:07:27 INFO]: Constructing module Variant Selector...
# [14:07:27 INFO]: Constructing module Vertical Planks...
# [14:07:27 INFO]: Constructing module Vertical Slabs...
# [14:07:27 INFO]: Constructing module Vexes Die With Their Masters...
# [14:07:27 INFO]: Constructing module Villager Rerolling Rework...
# [14:07:27 INFO]: Constructing module Villagers Follow Emeralds...
# [14:07:27 INFO]: Constructing module Wooden Posts...
# [14:07:27 INFO]: Constructing module Wool Shuts Up Minecarts...
# [14:07:27 INFO]: Constructing module Wraith...
# [14:07:27 INFO]: Constructing module Zombie Villagers On Normal...
# [14:07:27 INFO]: Constructing module More Stone Variants...
# [14:07:27 INFO]: Constructed 160 modules.
# [14:07:27 WARN]: Configuration file /workspaces/codespaces-jupyter/Minecraft-server/config/quark-common.toml is not correct. Correcting
# [14:07:28 INFO]: Dispatching ZRegister to 3 listeners
# [14:07:28 INFO]: Dispatching ZRegister$Post to 1 listener
# [14:07:28 INFO]: Dispatching ZRegister to 96 listeners
# [14:07:30 INFO]: Dispatching ZRegister$Post to 6 listeners
# [14:07:34 INFO]: Initialized block sets in 28ms
# [14:07:34 ERROR]: Could not find parent net/minecraft/client/particle/TextureSheetParticle for class it/hurts/sskirillss/octolib/particle/BasicColoredParticle in classloader cpw.mods.modlauncher.TransformingClassLoader@7856f41a on thread Thread[#1,main,5,main]
# [14:07:34 ERROR]: An error occurred building event handler
# java.lang.ClassNotFoundException: net.minecraft.client.particle.TextureSheetParticle
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:157) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.buildEvents(EventSubclassTransformer.java:97) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.transform(EventSubclassTransformer.java:48) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.EventBusEngine.processClass(EventBusEngine.java:26) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.service.ModLauncherService.processClassWithFlags(ModLauncherService.java:32) ~[eventbus-6.0.5.jar:6.0.5+0+master.c510e2cc]
# 	at cpw.mods.modlauncher.LaunchPluginHandler.offerClassNodeToPlugins(LaunchPluginHandler.java:88) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.modlauncher.ClassTransformer.transform(ClassTransformer.java:120) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.modlauncher.TransformingClassLoader.maybeTransformClassBytes(TransformingClassLoader.java:50) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.readerToClass(ModuleClassLoader.java:121) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.lambda$findClass$15(ModuleClassLoader.java:257) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.loadFromModule(ModuleClassLoader.java:267) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.findClass(ModuleClassLoader.java:257) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:144) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	at java.lang.ClassLoader.defineClass0(Native Method) ~[?:?]
# 	at java.lang.System$2.defineClass(System.java:2394) ~[?:?]
# 	at java.lang.invoke.MethodHandles$Lookup$ClassDefiner.defineClass(MethodHandles.java:2505) ~[?:?]
# 	at java.lang.invoke.InnerClassLambdaMetafactory.generateInnerClass(InnerClassLambdaMetafactory.java:361) ~[?:?]
# 	at java.lang.invoke.InnerClassLambdaMetafactory.spinInnerClass(InnerClassLambdaMetafactory.java:286) ~[?:?]
# 	at java.lang.invoke.InnerClassLambdaMetafactory.buildCallSite(InnerClassLambdaMetafactory.java:221) ~[?:?]
# 	at java.lang.invoke.LambdaMetafactory.metafactory(LambdaMetafactory.java:341) ~[?:?]
# 	at java.lang.invoke.BootstrapMethodInvoker.invoke(BootstrapMethodInvoker.java:134) ~[?:?]
# 	at java.lang.invoke.CallSite.makeSite(CallSite.java:316) ~[?:?]
# 	at java.lang.invoke.MethodHandleNatives.linkCallSiteImpl(MethodHandleNatives.java:274) ~[?:?]
# 	at java.lang.invoke.MethodHandleNatives.linkCallSite(MethodHandleNatives.java:264) ~[?:?]
# 	at it.hurts.sskirillss.octolib.particle.BasicColoredParticle$Options.<clinit>(BasicColoredParticle.java:271) ~[octolib-1.20.1-0.3.jar%23356!/:1.20.1-0.3]
# 	at it.hurts.sskirillss.octolib.particle.BasicColoredParticle$Factory$Type.<init>(BasicColoredParticle.java:329) ~[octolib-1.20.1-0.3.jar%23356!/:1.20.1-0.3]
# 	at net.minecraftforge.registries.DeferredRegister.lambda$addEntries$1(DeferredRegister.java:386) ~[forge-1.20.1-47.2.20-universal.jar%23399!/:?]
# 	at net.minecraftforge.registries.RegisterEvent.register(RegisterEvent.java:59) ~[forge-1.20.1-47.2.20-universal.jar%23399!/:?]
# 	at net.minecraftforge.registries.DeferredRegister.addEntries(DeferredRegister.java:386) ~[forge-1.20.1-47.2.20-universal.jar%23399!/:?]
# 	at net.minecraftforge.registries.DeferredRegister$EventDispatcher.handleEvent(DeferredRegister.java:328) ~[forge-1.20.1-47.2.20-universal.jar%23399!/:?]
# 	at net.minecraftforge.registries.__EventDispatcher_handleEvent_RegisterEvent.invoke(.dynamic) ~[?:?]
# 	at net.minecraftforge.eventbus.ASMEventHandler.invoke(ASMEventHandler.java:73) ~[eventbus-6.0.5.jar%23145!/:?]
# 	at net.minecraftforge.eventbus.EventBus.post(EventBus.java:319) ~[eventbus-6.0.5.jar%23145!/:?]
# 	at net.minecraftforge.eventbus.EventBus.post(EventBus.java:299) ~[eventbus-6.0.5.jar%23145!/:?]
# 	at net.minecraftforge.fml.javafmlmod.FMLModContainer.acceptEvent(FMLModContainer.java:155) ~[javafmllanguage-1.20.1-47.2.20.jar%23396!/:?]
# 	at net.minecraftforge.fml.ModLoader.lambda$postEventWithWrapInModOrder$33(ModLoader.java:346) ~[fmlcore-1.20.1-47.2.20.jar%23395!/:?]
# 	at java.lang.Iterable.forEach(Iterable.java:75) ~[?:?]
# 	at net.minecraftforge.fml.ModList.forEachModInOrder(ModList.java:227) ~[fmlcore-1.20.1-47.2.20.jar%23395!/:?]
# 	at net.minecraftforge.fml.ModLoader.postEventWithWrapInModOrder(ModLoader.java:344) ~[fmlcore-1.20.1-47.2.20.jar%23395!/:?]
# 	at net.minecraftforge.fml.ModLoader.postEventWrapContainerInModOrder(ModLoader.java:337) ~[fmlcore-1.20.1-47.2.20.jar%23395!/:?]
# 	at net.minecraftforge.registries.GameData.postRegisterEvents(GameData.java:329) ~[forge-1.20.1-47.2.20-universal.jar%23399!/:?]
# 	at net.minecraftforge.common.ForgeStatesProvider.lambda$new$4(ForgeStatesProvider.java:25) ~[forge-1.20.1-47.2.20-universal.jar%23399!/:?]
# 	at net.minecraftforge.fml.ModLoader.handleInlineTransition(ModLoader.java:217) ~[fmlcore-1.20.1-47.2.20.jar%23395!/:?]
# 	at net.minecraftforge.fml.ModLoader.lambda$dispatchAndHandleError$19(ModLoader.java:209) ~[fmlcore-1.20.1-47.2.20.jar%23395!/:?]
# 	at java.util.Optional.ifPresent(Optional.java:178) ~[?:?]
# 	at net.minecraftforge.fml.ModLoader.dispatchAndHandleError(ModLoader.java:209) ~[fmlcore-1.20.1-47.2.20.jar%23395!/:?]
# 	at net.minecraftforge.fml.ModLoader.lambda$gatherAndInitializeMods$13(ModLoader.java:183) ~[fmlcore-1.20.1-47.2.20.jar%23395!/:?]
# 	at java.lang.Iterable.forEach(Iterable.java:75) ~[?:?]
# 	at net.minecraftforge.fml.ModLoader.gatherAndInitializeMods(ModLoader.java:183) ~[fmlcore-1.20.1-47.2.20.jar%23395!/:?]
# 	at net.minecraftforge.server.loading.ServerModLoader.load(ServerModLoader.java:30) ~[forge-1.20.1-47.2.20-universal.jar%23399!/:?]
# 	at net.minecraft.server.Main.main(Main.java:165) ~[server-1.20.1-20230612.114412-srg.jar%23394!/:?]
# 	at jdk.internal.reflect.DirectMethodHandleAccessor.invoke(DirectMethodHandleAccessor.java:103) ~[?:?]
# 	at java.lang.reflect.Method.invoke(Method.java:580) ~[?:?]
# 	at net.minecraftforge.fml.loading.targets.CommonLaunchHandler.runTarget(CommonLaunchHandler.java:111) ~[fmlloader-1.20.1-47.2.20.jar%23186!/:?]
# 	at net.minecraftforge.fml.loading.targets.CommonLaunchHandler.serverService(CommonLaunchHandler.java:103) ~[fmlloader-1.20.1-47.2.20.jar%23186!/:?]
# 	at net.minecraftforge.fml.loading.targets.CommonServerLaunchHandler.lambda$makeService$0(CommonServerLaunchHandler.java:27) ~[fmlloader-1.20.1-47.2.20.jar%23186!/:?]
# 	at cpw.mods.modlauncher.LaunchServiceHandlerDecorator.launch(LaunchServiceHandlerDecorator.java:30) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.LaunchServiceHandler.launch(LaunchServiceHandler.java:53) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.LaunchServiceHandler.launch(LaunchServiceHandler.java:71) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.Launcher.run(Launcher.java:108) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.Launcher.main(Launcher.java:78) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.BootstrapLaunchConsumer.accept(BootstrapLaunchConsumer.java:26) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.BootstrapLaunchConsumer.accept(BootstrapLaunchConsumer.java:23) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.bootstraplauncher.BootstrapLauncher.main(BootstrapLauncher.java:141) [bootstraplauncher-1.1.2.jar:?]
# 	at com.mohistmc.MohistMCStart.main(MohistMCStart.java:106) [mohist.jar:1.20.1-580]
# [14:07:36 INFO]: Dispatching ForgeZEntityAttributeCreation (as ZEntityAttributeCreation) to 7 listeners
# [14:07:37 INFO]: Loading common config for mutantmonsters
# [14:07:37 INFO]: Dispatching ZConfigChanged to 2 listeners
# [14:07:37 INFO]: 'zeta' is enabling Zeta's piston structure resolver.
# [14:07:37 INFO]: Dispatching ZConfigChanged to 45 listeners
# [14:07:37 INFO]: Dispatching ZConfigChanged to 45 listeners
# [14:07:37 INFO]: Common Setup
# [14:07:37 INFO]: Registered region minecraft:overworld to index 0 for type OVERWORLD
# [14:07:37 INFO]: Registered region minecraft:nether to index 0 for type NETHER
# [14:07:37 INFO]: Registered region regions_unexplored:primary to index 1 for type OVERWORLD
# [14:07:37 INFO]: Registered region regions_unexplored:secondary to index 2 for type OVERWORLD
# [14:07:37 INFO]: Registered region regions_unexplored:nether to index 1 for type NETHER
# [14:07:37 INFO]: Dispatching ForgeZCommonSetup (as ZCommonSetup) to 2 listeners
# [14:07:37 INFO]: Dispatching ForgeZCommonSetup (as ZCommonSetup) to 40 listeners
# [14:07:37 INFO]: Registered region biomesoplenty:overworld_primary to index 3 for type OVERWORLD
# [14:07:37 INFO]: Registered region biomesoplenty:overworld_secondary to index 4 for type OVERWORLD
# [14:07:37 INFO]: Registered region biomesoplenty:overworld_rare to index 5 for type OVERWORLD
# [14:07:37 INFO]: Registered region biomesoplenty:nether_common to index 2 for type NETHER
# [14:07:37 INFO]: Registered region biomesoplenty:nether_rare to index 3 for type NETHER
# [14:07:37 INFO]: Initialized color sets in 56ms
# [14:07:37 INFO]: Registered region ars_nouveau:overworld to index 6 for type OVERWORLD
# [14:07:37 INFO]: Dispatching ZConfigChanged to 2 listeners
# [14:07:37 INFO]: Dispatching ZConfigChanged to 45 listeners
# [14:07:37 INFO]: Registered region quark:biome_provider to index 7 for type OVERWORLD
# [14:07:37 INFO]: Finished mod setup in: [15, 2, 0, 0, 0, 0, 8, 0] ms
# [14:07:37 INFO]: Got IMC []
# [14:07:37 INFO]: Dispatching ForgeZLoadComplete (as ZLoadComplete) to 1 listener
# [14:07:37 INFO]: Dispatching ForgeZLoadComplete (as ZLoadComplete) to 6 listeners
# [14:07:45 INFO]: Environment: authHost='https://authserver.mojang.com', accountsHost='https://api.mojang.com', sessionHost='https://sessionserver.mojang.com', servicesHost='https://api.minecraftservices.com', name='PROD'
# [14:07:45 WARN]: DataFixLevelStorageSourceMixin failed to load ./world/level.dat, ./world/level.dat (No such file or directory)
# [14:07:45 WARN]: DataFixLevelStorageSourceMixin failed to load ./world/level.dat, ./world/level.dat (No such file or directory)
# [14:07:45 WARN]: DataFixLevelStorageSourceMixin failed to load ./world/level.dat, ./world/level.dat (No such file or directory)
# [14:07:45 ERROR]: Cristel Lib Config Pack has no data
# [14:07:45 INFO]: Found new data pack Supplementaries Generated Pack, loading it automatically
# [14:07:45 INFO]: Found new data pack hordes-config, loading it automatically
# [14:07:45 INFO]: Found new data pack mutantmonsters:biome_modifications, loading it automatically
# [14:07:46 INFO]: Generated runtime SERVER_DATA for pack Supplementaries Generated Pack (supplementaries) in: 49 ms
# [14:07:46 ERROR]: Invalid path in pack: fokastudio:worldgen/biome/README.md, ignoring
# [14:07:47 INFO]: Structure placement for `awesomedungeon:abandoned_oak_palace/start_pool`: { spacing: 50, separation: 25, salt: 1694767080, useValueFromConfiguration: true}
# [14:07:47 INFO]: Structure placement for `awesomedungeonend:aws_all_end_structures/start_pool`: { spacing: 20, separation: 15, salt: 49082056, useValueFromConfiguration: true}
# [14:07:47 INFO]: Structure placement for `awesomedungeon:better_default_jungle_temple/start_pool`: { spacing: 50, separation: 25, salt: 1654787080, useValueFromConfiguration: true}
# [14:07:47 INFO]: Structure placement for `awesomedungeon:desert_temple_husk/start_pool`: { spacing: 50, separation: 25, salt: 1394767080, useValueFromConfiguration: true}
# [14:07:47 INFO]: Structure placement for `awesomedungeon:jungle_giant_tree/start_pool`: { spacing: 50, separation: 25, salt: 1494763380, useValueFromConfiguration: true}
# [14:07:47 INFO]: Structure placement for `awesomedungeon:mushroom_abandonned/start_pool`: { spacing: 50, separation: 25, salt: 1494227080, useValueFromConfiguration: true}
# [14:07:47 INFO]: Structure placement for `awesomedungeonnether:nth_absi_palace/start_pool`: { spacing: 50, separation: 25, salt: 19482856, useValueFromConfiguration: true}
# [14:07:47 INFO]: Structure placement for `awesomedungeonnether:nth_accum_quad/start_pool`: { spacing: 50, separation: 25, salt: 28482856, useValueFromConfiguration: true}
# [14:07:47 INFO]: Structure placement for `awesomedungeonnether:nth_blaze_tower/start_pool`: { spacing: 50, separation: 25, salt: 37482856, useValueFromConfiguration: true}
# [14:07:47 INFO]: Structure placement for `awesomedungeonnether:nth_center_square/start_pool`: { spacing: 50, separation: 25, salt: 46482856, useValueFromConfiguration: true}
# [14:07:47 INFO]: Structure placement for `awesomedungeonnether:nth_giant_crimson_tree/start_pool`: { spacing: 50, separation: 25, salt: 55482856, useValueFromConfiguration: true}
# [14:07:47 INFO]: Structure placement for `awesomedungeonnether:nth_obsi_house/start_pool`: { spacing: 50, separation: 25, salt: 64482856, useValueFromConfiguration: true}
# [14:07:47 INFO]: Structure placement for `awesomedungeon:swamp_big_temple/start_pool`: { spacing: 50, separation: 25, salt: 1594763280, useValueFromConfiguration: true}
# [14:07:47 INFO]: Structure placement for `awesomedungeon:the_usine/start_pool`: { spacing: 50, separation: 25, salt: 1694767078, useValueFromConfiguration: true}
# [14:07:47 INFO]: Structure placement for `awesomedungeon:t_z_tower/start_pool`: { spacing: 50, separation: 25, salt: 1794767078, useValueFromConfiguration: true}
# [14:07:47 INFO]: Structure placement for `awesomedungeon:witch_castle/start_pool`: { spacing: 50, separation: 25, salt: 1894776078, useValueFromConfiguration: true}
# [14:07:48 WARN]: DataFixLevelStorageSourceMixin failed to load ./world/level.dat, ./world/level.dat (No such file or directory)
# [14:07:48 INFO]: Replaced 2 calls to Enchantment#getMaxLevel() in net/minecraft/server/commands/EnchantCommand
# [14:07:49 INFO]: Adding datapack listener capsid_recipes
# [14:07:49 INFO]: Adding datapack listener altar_of_amethyst_recipes
# [14:07:49 INFO]: Dispatching ForgeZAddReloadListener (as ZAddReloadListener) to 2 listeners
# [14:07:49 INFO]: Dispatching ForgeZAddReloadListener (as ZAddReloadListener) to 2 listeners
# [14:07:49 INFO]: Dispatching AdvancementModifierRegistry$1 (as ZGatherAdvancementModifiers) to 1 listener
# [14:07:55 INFO]: Registered 33 additional loot tables.
# [14:07:55 INFO]: Skipping loading recipe supplementaries:inspirations/blackboard_clear as it's serializer returned null
# [14:07:55 INFO]: Skipping loading recipe mob_grinding_utils:beheading/drowned as it's serializer returned null
# [14:07:55 INFO]: Skipping loading recipe mob_grinding_utils:beheading/piglin as it's serializer returned null
# [14:07:55 ERROR]: Parsing error loading recipe create:cutting/compat/biomesoplenty/stripped_cherry_log
# com.google.gson.JsonSyntaxException: Unknown item 'biomesoplenty:stripped_cherry_log'
# 	at net.minecraft.world.item.crafting.ShapedRecipe.m_151280_(ShapedRecipe.java:361) ~[server-1.20.1-20230612.114412-srg.jar%23394!/:?]
# 	at java.util.Optional.orElseThrow(Optional.java:403) ~[?:?]
# 	at net.minecraft.world.item.crafting.ShapedRecipe.m_151278_(ShapedRecipe.java:360) ~[server-1.20.1-20230612.114412-srg.jar%23394!/:?]
# 	at net.minecraft.world.item.crafting.Ingredient.m_43919_(Ingredient.java:229) ~[server-1.20.1-20230612.114412-srg.jar%23394!/:?]
# 	at net.minecraftforge.common.crafting.VanillaIngredientSerializer.parse(VanillaIngredientSerializer.java:27) ~[forge-1.20.1-47.2.20-universal.jar%23399!/:?]
# 	at net.minecraftforge.common.crafting.CraftingHelper.getIngredient(CraftingHelper.java:148) ~[forge-1.20.1-47.2.20-universal.jar%23399!/:?]
# 	at net.minecraft.world.item.crafting.Ingredient.m_288218_(Ingredient.java:204) ~[server-1.20.1-20230612.114412-srg.jar%23394!/:?]
# 	at net.minecraft.world.item.crafting.Ingredient.m_43917_(Ingredient.java:199) ~[server-1.20.1-20230612.114412-srg.jar%23394!/:?]
# 	at com.simibubi.create.content.processing.recipe.ProcessingRecipeSerializer.readFromJson(ProcessingRecipeSerializer.java:66) ~[create-1.20.1-0.5.1.f.jar%23325!/:0.5.1.f]
# 	at com.simibubi.create.content.processing.recipe.ProcessingRecipeSerializer.fromJson(ProcessingRecipeSerializer.java:154) ~[create-1.20.1-0.5.1.f.jar%23325!/:0.5.1.f]
# 	at com.simibubi.create.content.processing.recipe.ProcessingRecipeSerializer.m_6729_(ProcessingRecipeSerializer.java:21) ~[create-1.20.1-0.5.1.f.jar%23325!/:0.5.1.f]
# 	at net.minecraftforge.common.extensions.IForgeRecipeSerializer.fromJson(IForgeRecipeSerializer.java:23) ~[forge-1.20.1-47.2.20-universal.jar%23399!/:?]
# 	at net.minecraft.world.item.crafting.RecipeManager.fromJson(RecipeManager.java:186) ~[server-1.20.1-20230612.114412-srg.jar%23394!/:?]
# 	at net.minecraft.world.item.crafting.RecipeManager.m_5787_(RecipeManager.java:77) ~[server-1.20.1-20230612.114412-srg.jar%23394!/:?]
# 	at net.minecraft.world.item.crafting.RecipeManager.m_5787_(RecipeManager.java:37) ~[server-1.20.1-20230612.114412-srg.jar%23394!/:?]
# 	at net.minecraft.server.packs.resources.SimplePreparableReloadListener.m_10789_(SimplePreparableReloadListener.java:13) ~[server-1.20.1-20230612.114412-srg.jar%23394!/:?]
# 	at java.util.concurrent.CompletableFuture$UniAccept.tryFire(CompletableFuture.java:718) ~[?:?]
# 	at java.util.concurrent.CompletableFuture$Completion.run(CompletableFuture.java:482) ~[?:?]
# 	at net.minecraft.server.packs.resources.SimpleReloadInstance.m_143940_(SimpleReloadInstance.java:69) ~[server-1.20.1-20230612.114412-srg.jar%23394!/:?]
# 	at net.minecraft.Util.m_214652_(Util.java:783) ~[server-1.20.1-20230612.114412-srg.jar%23394!/:?]
# 	at net.minecraft.Util.m_214679_(Util.java:772) ~[server-1.20.1-20230612.114412-srg.jar%23394!/:?]
# 	at net.minecraft.server.Main.main(Main.java:220) ~[server-1.20.1-20230612.114412-srg.jar%23394!/:?]
# 	at jdk.internal.reflect.DirectMethodHandleAccessor.invoke(DirectMethodHandleAccessor.java:103) ~[?:?]
# 	at java.lang.reflect.Method.invoke(Method.java:580) ~[?:?]
# 	at net.minecraftforge.fml.loading.targets.CommonLaunchHandler.runTarget(CommonLaunchHandler.java:111) ~[fmlloader-1.20.1-47.2.20.jar%23186!/:?]
# 	at net.minecraftforge.fml.loading.targets.CommonLaunchHandler.serverService(CommonLaunchHandler.java:103) ~[fmlloader-1.20.1-47.2.20.jar%23186!/:?]
# 	at net.minecraftforge.fml.loading.targets.CommonServerLaunchHandler.lambda$makeService$0(CommonServerLaunchHandler.java:27) ~[fmlloader-1.20.1-47.2.20.jar%23186!/:?]
# 	at cpw.mods.modlauncher.LaunchServiceHandlerDecorator.launch(LaunchServiceHandlerDecorator.java:30) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.LaunchServiceHandler.launch(LaunchServiceHandler.java:53) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.LaunchServiceHandler.launch(LaunchServiceHandler.java:71) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.Launcher.run(Launcher.java:108) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.Launcher.main(Launcher.java:78) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.BootstrapLaunchConsumer.accept(BootstrapLaunchConsumer.java:26) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.modlauncher.BootstrapLaunchConsumer.accept(BootstrapLaunchConsumer.java:23) [modlauncher-10.0.9.jar%23101!/:?]
# 	at cpw.mods.bootstraplauncher.BootstrapLauncher.main(BootstrapLauncher.java:141) [bootstraplauncher-1.1.2.jar:?]
# 	at com.mohistmc.MohistMCStart.main(MohistMCStart.java:106) [mohist.jar:1.20.1-580]
# [14:07:55 INFO]: Skipping loading recipe twilightforest:jeed/frosted as it's serializer returned null
# [14:07:55 INFO]: Skipping loading recipe supplementaries:inspirations/flag_dye as it's serializer returned null
# [14:07:55 INFO]: Skipping loading recipe twilightforest:jeed/hunger as it's serializer returned null
# [14:07:55 INFO]: Skipping loading recipe mob_grinding_utils:beheading/zombified_piglin_brute as it's serializer returned null
# [14:07:55 ERROR]: Parsing error loading recipe create:cutting/compat/biomesoplenty/cherry_log
# com.google.gson.JsonSyntaxException: Unknown item 'biomesoplenty:cherry_log'
# 	at net.minecraft.world.item.crafting.ShapedRecipe.m_151280_(ShapedRecipe.java:361) ~[server-1.20.1-20230612.114412-srg.jar%23394!/:?]
# 	at java.util.Optional.orElseThrow(Optional.java:403) ~[?:?]
# 	at net.minecraft.world.item.crafting.ShapedRecipe.m_151278_(ShapedRecipe.java:360) ~[server-1.20.1-20230612.114412-srg.jar%23394!/:?]
# 	at net.minecraft.world.item.crafting.Ingredient.m_43919_(Ingredient.java:229) ~[server-1.20.1-20230612.114412-srg.jar%23394!/:?]
# 	at net.minecraftforge.common.crafting.VanillaIngredientSerializer.parse(VanillaIngredientSerializer.java:27) ~[forge-1.20.1-47.2.20-universal.jar%23399!/:?]
# 	at net.minecraftforge.common.crafting.CraftingHelper.getIngredient(CraftingHelper.java:148) ~[forge-1.20.1-47.2.20-universal.jar%23399!/:?]
# 	at net.minecraft.world.item.crafting.Ingredient.m_288218_(Ingredient.java:204) ~[server-1.20.1-20230612.114412-srg.jar%23394!/:?]
# 	at net.minecraft.world.item.crafting.Ingredient.m_43917_(Ingredient.java:199) ~[server-1.20.1-20230612.114412-srg.jar%23394!/:?]
# 	at com.simibubi.create.content.processing.recipe.ProcessingRecipeSerializer.readFromJson(ProcessingRecipeSerializer.java:66) ~[create-1.20.1-0.5.1.f.jar%23325!/:0.5.1.f]
# 	at com.simibubi.create.content.processing.recipe.ProcessingRecipeSerializer.fromJson(ProcessingRecipeSerializer.java:154) ~[create-1.20.1-0.5.1.f.jar%23325!/:0.5.1.f]
# 	at com.simibubi.create.content.processing.recipe.ProcessingRecipeSerializer.m_6729_(ProcessingRecipeSerializer.java:21) ~[create-1.20.1-0.5.1.f.jar%23325!/:0.5.1.f]
# ...
# [14:12:28 INFO]: Preparing spawn area: 5%
# [14:12:29 INFO]: Preparing spawn area: 5%
# [14:12:29 INFO]: Preparing spawn area: 6%
# [14:12:30 INFO]: Preparing spawn area: 8%
# [14:12:30 INFO]: Preparing spawn area: 10%
# [14:12:31 INFO]: Preparing spawn area: 10%
# [14:12:31 INFO]: Preparing spawn area: 11%
# [14:12:32 INFO]: Preparing spawn area: 14%
# [14:12:32 INFO]: Preparing spawn area: 14%
# [14:12:33 INFO]: Preparing spawn area: 16%
# [14:12:33 INFO]: Preparing spawn area: 17%
# [14:12:34 INFO]: Preparing spawn area: 18%
# [14:12:34 INFO]: Preparing spawn area: 20%
# [14:12:35 INFO]: Preparing spawn area: 22%
# [14:12:35 INFO]: Preparing spawn area: 24%
# [14:12:36 INFO]: Preparing spawn area: 25%
# [14:12:37 INFO]: Preparing spawn area: 26%
# [14:12:37 INFO]: Preparing spawn area: 26%
# [14:12:37 INFO]: Preparing spawn area: 27%
# [14:12:38 INFO]: Preparing spawn area: 30%
# [14:12:38 INFO]: Preparing spawn area: 31%
# [14:12:39 INFO]: Preparing spawn area: 32%
# [14:12:39 INFO]: Preparing spawn area: 33%
# [14:12:40 INFO]: Preparing spawn area: 34%
# [14:12:40 INFO]: Preparing spawn area: 35%
# [14:12:41 INFO]: Preparing spawn area: 37%
# [14:12:41 INFO]: Preparing spawn area: 40%
# [14:12:42 INFO]: Preparing spawn area: 42%
# [14:12:42 INFO]: Preparing spawn area: 43%
# [14:12:43 INFO]: Preparing spawn area: 44%
# [14:12:43 INFO]: Preparing spawn area: 45%
# [14:12:44 INFO]: Preparing spawn area: 47%
# [14:12:44 INFO]: Preparing spawn area: 50%
# [14:12:45 INFO]: Preparing spawn area: 53%
# [14:12:46 INFO]: Preparing spawn area: 54%
# [14:12:46 INFO]: Preparing spawn area: 54%
# [14:12:47 INFO]: Preparing spawn area: 55%
# [14:12:47 INFO]: Preparing spawn area: 55%
# [14:12:48 INFO]: Preparing spawn area: 55%
# [14:12:48 INFO]: Preparing spawn area: 55%
# [14:12:48 INFO]: Preparing spawn area: 55%
# [14:12:49 INFO]: Preparing spawn area: 55%
# [14:12:50 INFO]: Preparing spawn area: 56%
# [14:12:50 INFO]: Preparing spawn area: 56%
# [14:12:50 INFO]: Preparing spawn area: 58%
# [14:12:51 INFO]: Preparing spawn area: 60%
# [14:12:51 INFO]: Preparing spawn area: 62%
# [14:12:52 INFO]: Preparing spawn area: 65%
# [14:12:52 INFO]: Preparing spawn area: 67%
# [14:12:53 INFO]: Preparing spawn area: 68%
# [14:12:53 INFO]: Preparing spawn area: 68%
# [14:12:54 INFO]: Preparing spawn area: 70%
# [14:12:54 INFO]: Preparing spawn area: 72%
# [14:12:55 INFO]: Preparing spawn area: 74%
# [14:12:55 INFO]: Preparing spawn area: 74%
# [14:12:56 INFO]: Preparing spawn area: 77%
# [14:12:56 INFO]: Preparing spawn area: 80%
# [14:12:57 INFO]: Preparing spawn area: 82%
# [14:12:57 INFO]: Preparing spawn area: 83%
# [14:12:58 INFO]: Preparing spawn area: 83%
# [14:12:59 INFO]: Preparing spawn area: 83%
# [14:12:59 INFO]: Preparing spawn area: 83%
# [14:12:59 INFO]: Preparing spawn area: 84%
# [14:13:00 INFO]: Preparing spawn area: 85%
# [14:13:00 INFO]: Preparing spawn area: 88%
# [14:13:01 INFO]: Preparing spawn area: 89%
# [14:13:01 INFO]: Preparing spawn area: 92%
# [14:13:02 INFO]: Preparing spawn area: 93%
# [14:13:02 INFO]: Preparing spawn area: 96%
# [14:13:03 INFO]: Preparing spawn area: 97%
# [14:13:03 INFO]: Time elapsed: 49930 ms
# [14:13:03 INFO]: [AdvancedTeleport] Enabling AdvancedTeleport v6.0.0
# [14:13:03 INFO]: [AdvancedTeleport] Performing server version check.
# [14:13:03 INFO]: [AdvancedTeleport] Detected major version: 20
# [14:13:03 INFO]: [AdvancedTeleport] Advanced Teleport is now enabling...
# [14:13:03 INFO]: [AdvancedTeleport] Setting up permissions integration with Vault.
# [14:13:03 INFO]: [AdvancedTeleport] Vault is not on the server, skipping.
# [14:13:03 INFO]: [AdvancedTeleport] Loading MainConfig.
# [14:13:03 WARN]: [AdvancedTeleport] Failed to parse payment 100.0 for command tpa! Error message: net/milkbowl/vault/economy/Economy
# [14:13:03 WARN]: [AdvancedTeleport] Failed to parse payment 100.0 for command tpahere! Error message: net/milkbowl/vault/economy/Economy
# [14:13:03 WARN]: [AdvancedTeleport] Failed to parse payment 100.0 for command tpr! Error message: net/milkbowl/vault/economy/Economy
# [14:13:03 WARN]: [AdvancedTeleport] Failed to parse payment 100.0 for command spawn! Error message: net/milkbowl/vault/economy/Economy
# [14:13:03 WARN]: [AdvancedTeleport] Failed to parse payment 100.0 for command warp! Error message: net/milkbowl/vault/economy/Economy
# [14:13:03 WARN]: [AdvancedTeleport] Failed to parse payment 100.0 for command home! Error message: net/milkbowl/vault/economy/Economy
# [14:13:03 WARN]: [AdvancedTeleport] Failed to parse payment 100.0 for command back! Error message: net/milkbowl/vault/economy/Economy
# [14:13:05 INFO]: [AdvancedTeleport] Registered the image warp_default!
# [14:13:05 INFO]: [AdvancedTeleport] Registered the image home_default!
# [14:13:05 INFO]: [AdvancedTeleport] Registered the image spawn_default!
# [14:13:05 INFO]: [ReviveMe] Enabling ReviveMe v0.4.4
# [14:13:05 INFO]: ReviveMe enable
# [14:13:05 INFO]: [Mohist] Enabling Mohist v1.20.1
# [14:13:05 INFO]: Server permissions file permissions.yml is empty, ignoring it
# [14:13:05 INFO]: Done (293.000s)! For help, type "help"
# [14:13:05 INFO]: Successfully initialized permission handler forge:default_handler
# [14:13:05 INFO]: Forwarding forge permission[forge:default_handler] to bukkit[mohist:permission]
# [14:13:05 INFO]: Thanks for choosing Structory!
# [14:13:05 INFO]: Thanks for choosing Terralith!
# [14:13:05 INFO]: Loading infobook /data/cyclopscore/info/test.xml
# [14:13:05 INFO]: {iceandfire:fire_dragon_roost=true, iceandfire:fire_lily=true, iceandfire:spawn_dragon_skeleton_fire=true, iceandfire:lightning_dragon_roost=true, iceandfire:spawn_dragon_skeleton_lightning=true, iceandfire:ice_dragon_roost=true, iceandfire:ice_dragon_cave=true, iceandfire:lightning_dragon_cave=true, iceandfire:cyclops_cave=true, iceandfire:spawn_wandering_cyclops=true, iceandfire:spawn_sea_serpent=true, iceandfire:frost_lily=true, iceandfire:hydra_cave=true, iceandfire:lightning_lily=true, iceandfire:pixie_village=true, iceandfire:myrmex_hive_jungle=true, iceandfire:myrmex_hive_desert=true, iceandfire:silver_ore=true, iceandfire:siren_island=true, iceandfire:spawn_dragon_skeleton_ice=true, iceandfire:spawn_stymphalian_bird=true, iceandfire:fire_dragon_cave=true, iceandfire:sapphire_ore=true, iceandfire:spawn_hippocampus=true, iceandfire:spawn_death_worm=true}
# [14:13:05 INFO]: {TROLL_S=true, HIPPOGRYPH=true, AMPHITHERE=true, COCKATRICE=true, TROLL_M=true, DREAD_LICH=true, TROLL_F=true}
# [14:13:05 INFO]: Disconnecting Player (server is still starting): literal{Server is still starting! Please wait before reconnecting.}
# [14:13:05 INFO]: Disconnecting Player (server is still starting): literal{Server is still starting! Please wait before reconnecting.}
# [14:13:06 INFO]: Encoded Weapon Attribute registry size (with package overhead): 379360 bytes (in 38 string chunks with the size of 10000)
# [14:13:06 INFO]: Sending reload packet to clients
# [14:13:06 INFO]: [ReviveMe] There is not a new update available.
# [14:13:06 INFO]: [SkinsRestorer] ----------------------------------------------
# [14:13:06 INFO]: [SkinsRestorer]     +==================+
# [14:13:06 INFO]: [SkinsRestorer]     |   SkinsRestorer  |
# [14:13:06 INFO]: [SkinsRestorer]     |------------------|
# [14:13:06 INFO]: [SkinsRestorer]     |  Standalone Mode |
# [14:13:06 INFO]: [SkinsRestorer]     +==================+
# [14:13:06 INFO]: [SkinsRestorer] ----------------------------------------------
# [14:13:06 INFO]: [SkinsRestorer]     Version: 15.0.7
# [14:13:06 INFO]: [SkinsRestorer]     Commit: 301d078
# [14:13:06 INFO]: [SkinsRestorer]     This is the latest version!
# [14:13:06 INFO]: [SkinsRestorer] ----------------------------------------------
# [14:13:06 INFO]: [AdvancedTeleport] Plugin is up to date!
# [14:13:08 INFO]: Found Pupfish chunk at -1489 ~ 1952 after 59 tries
# [14:13:19 WARN]: [AdvancedTeleport] First-join teleport point  does not exist.
# [14:13:19 INFO]: Sr_Small joined the game
# [14:13:20 INFO]: Sr_Small[/127.0.0.1:51798] logged in with entity id 17903 at ([world]157.5, 72.0, -118.5)
# [14:13:20 INFO]: Sr_Small has made the advancement [advancements.iceandfire.root.title]
# [14:13:20 INFO]: Sr_Small has made the advancement [Integrated Dungeons and Structures]
# [14:13:20 INFO]: Sr_Small has made the advancement [advancements.immersive_caves.title]
# [14:13:21 INFO]: Sr_Small has made the advancement [Rare Find]
# [14:16:20 INFO]: Sr_Small has made the advancement [lootr.advancements.1chest.title]
# [14:16:23 INFO]: Sr_Small has made the advancement [artifacts.advancements.amateur_archaeologist.title]
# [14:16:24 INFO]: Sr_Small has made the advancement [Ice Bucket Challenge]
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [14:16:56 WARN]: Empty or non-existent pool: minecraft:
# [14:16:56 WARN]: Empty or non-existent pool: minecraft:
# [14:18:14 WARN]: Sr_Small moved too quickly! -7.815293313210532,6.0,2.4156761657080636
# [14:18:18 INFO]: Sr_Small has made the advancement [advancements.apotheosis.gem]
# [14:18:26 INFO]: Sr_Small has made the advancement [advancements.apotheosis.rare_gem]
# [14:18:33 WARN]: Initializing Legacy Material Support. Unless you have legacy plugins and/or data this is a bug!
# [14:18:35 INFO]: Sr_Small has made the advancement [Acquire Hardware]
# [14:18:49 INFO]: Sr_Small died
# [14:18:55 INFO]: Sr_Small issued server command: /back
# [14:20:27 INFO]: Sr_Small has made the advancement [advancements.apotheosis.affix]
# [14:20:27 INFO]: Sr_Small has reached the goal [advancements.apotheosis.rare]
# [14:20:27 INFO]: Sr_Small has made the advancement [advancements.apotheosis.chests]
# [14:21:21 INFO]: Sr_Small has made the advancement [lootr.advancements.1barrel.title]
# [14:22:15 INFO]: Sr_Small has made the advancement [Stone Age]
# [14:22:24 INFO]: Sr_Small has made the advancement [Getting an Upgrade]
# [14:23:31 INFO]: Sr_Small died
# [14:23:35 INFO]: Sr_Small issued server command: /back
# [14:24:09 INFO]: Sr_Small has reached the goal [Eye of Darkness]
# [14:24:18 INFO]: Sr_Small has made the advancement [Isn't It Iron Pick]
# [14:24:49 INFO]: Sr_Small has made the advancement [lootr.advancements.10loot.title]
# [14:25:35 INFO]: Sr_Small has made the advancement [Sweet Dreams]
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [14:28:08 INFO]: death.attack.irons_spellbooks.cone_of_cold
# [14:28:10 INFO]: Sr_Small issued server command: /back
# [14:28:44 INFO]: Sr_Small died
# [14:28:47 INFO]: Sr_Small issued server command: /back
# [14:28:53 INFO]: Sr_Small issued server command: /back
# [14:28:57 INFO]: Sr_Small issued server command: /back
# [14:28:58 INFO]: death.attack.irons_spellbooks.summon_polar_bear
# [14:29:08 INFO]: Sr_Small issued server command: /back
# [14:29:20 INFO]: death.attack.irons_spellbooks.cone_of_cold
# [14:29:52 INFO]: Sr_Small issued server command: /back
# [14:30:01 INFO]: death.attack.irons_spellbooks.summon_polar_bear
# [14:32:03 INFO]: death.attack.irons_spellbooks.summon_polar_bear
# [14:32:11 INFO]: death.attack.irons_spellbooks.summon_polar_bear
# [14:32:34 INFO]: death.attack.irons_spellbooks.icicle
# [14:32:41 INFO]: death.attack.irons_spellbooks.summon_polar_bear
# [14:33:05 INFO]: death.attack.irons_spellbooks.summon_polar_bear
# [14:35:30 INFO]: LURKER spawned at BlockPos{x=0, y=70, z=115}
# [14:36:44 WARN]: Tried to load a DUMMY block entity @ BlockPos{x=-240, y=-34, z=333} but found not block entity block Block{minecraft:air} at location
# [14:36:44 WARN]: Tried to load a block entity for block Block{minecraft:air} but failed at location BlockPos{x=-240, y=-34, z=333}
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [14:38:23 INFO]: Sr_Small has made the advancement [advancements.thetear.title]
# [14:38:42 INFO]: Sr_Small has made the advancement [advancements.apotheosis.enchantment]
# [14:38:51 INFO]: Sr_Small has made the advancement [What a Deal!]
# [14:41:40 INFO]: Sr_Small issued server command: /tp Sr_Small 8.5 70 183.5
# [14:43:45 INFO]: Sr_Small died
# [14:43:48 INFO]: Sr_Small issued server command: /back
# [14:44:11 INFO]: Sr_Small was slain by entity.gamma_beasts.crasu_a
# [14:44:14 INFO]: Sr_Small issued server command: /back
# [14:45:14 INFO]: Sr_Small has made the advancement [advancement.dungeons_arise.find_foundry.title]
# [14:45:45 INFO]: Sr_Small was slain by Spider
# [14:45:49 INFO]: Sr_Small issued server command: /back
# [14:46:35 INFO]: Sr_Small has made the advancement [Suit Up]
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [14:47:06 INFO]: Sr_Small died
# [14:47:10 INFO]: Sr_Small issued server command: /back
# [14:47:48 INFO]: Sr_Small died
# [14:48:01 INFO]: Sr_Small issued server command: /back
# [14:48:24 INFO]: Sr_Small issued server command: /back
# [14:48:27 INFO]: Sr_Small died
# [14:48:41 INFO]: Sr_Small issued server command: /back
# [14:54:04 INFO]: Sr_Small was doomed to fall
# [14:54:07 INFO]: Sr_Small issued server command: /back
# [14:54:10 INFO]: LURKER spawned at BlockPos{x=270, y=96, z=136}
# [14:54:19 INFO]: Sr_Small died
# [14:54:27 INFO]: Sr_Small issued server command: /back
# [14:55:44 INFO]: Sr_Small died
# [14:55:48 INFO]: Sr_Small issued server command: /back
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [15:01:44 INFO]: Sr_Small was shot by Skeleton
# [15:02:00 INFO]: Sr_Small issued server command: /back
# [15:02:10 INFO]: Sr_Small was shot by Skeleton
# [15:02:14 INFO]: Sr_Small issued server command: /back
# [15:03:33 INFO]: Named entity DrownedPlayer['Sr_Small'/39446, l='ServerLevel[world]', x=343.30, y=56.66, z=244.70] died: Drowned Player was slain by Sr_Small
# [15:04:22 INFO]: Sr_Small has made the advancement [advancements.it_sparkles.title]
# >
